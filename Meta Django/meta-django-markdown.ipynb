# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Django is built for:-**
# - Text content
# - Media files
# - Heavy traffic

# %% [markdown]
# ---
# 1. Templates
# 2. Libraries
# 3. API

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Django provides **asynchronous views**<br>
# **Fault tolerance**

# %% [markdown]
# `python3 manage.py runserver # To run the server
# -python3 manage.py makemigrations # To compile the migrations
# -python3 manage.py migrate  # To migrate the changes in Database`
